# %%
pip install tensorflow keras numpy pandas opencv-python matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\akram\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\users\akram\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: numpy in c:\users\akram\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\akram\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: opencv-python in c:\users\akram\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\akram\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\akram\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: rich in c:\users\akram\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akram\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akram\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\akram\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow keras numpy pandas opencv-python matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\akram\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\users\akram\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: numpy in c:\users\akram\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\akram\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: opencv-python in c:\users\akram\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\akram\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\akram\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: rich in c:\users\akram\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\akram\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\akram\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akram\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akram\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\akram\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define constants
IMG_SIZE = (48, 48)  # FER-2013 images are 48x48 pixels
BATCH_SIZE = 64
EPOCHS = 25

# Load dataset from folders
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    r"C:\Users\akram\Downloads\archive (2)\train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical"
)

test_generator = test_datagen.flow_from_directory(
    r"C:\Users\akram\Downloads\archive (2)\test",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    color_mode="grayscale",
    class_mode="categorical"
)

# Build CNN Model
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')  # Output layer
])

# Compile the Model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the Model
model.fit(train_generator, validation_data=test_generator, epochs=EPOCHS)

# Save the Model
model.save("emotion_model.h5")

print("Model training complete! Saved as emotion_model.h5")
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# C:\Users\akram\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\akram\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 138s 300ms/step - accuracy: 0.2652 - loss: 1.7865 - val_accuracy: 0.4195 - val_loss: 1.5145
# Epoch 2/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 125s 279ms/step - accuracy: 0.4070 - loss: 1.5269 - val_accuracy: 0.4674 - val_loss: 1.3950
# Epoch 3/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 121s 269ms/step - accuracy: 0.4511 - loss: 1.4347 - val_accuracy: 0.4908 - val_loss: 1.3408
# Epoch 4/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 127s 283ms/step - accuracy: 0.4758 - loss: 1.3695 - val_accuracy: 0.5026 - val_loss: 1.3041
# Epoch 5/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 120s 267ms/step - accuracy: 0.4954 - loss: 1.3214 - val_accuracy: 0.5092 - val_loss: 1.2770
# Epoch 6/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 119s 265ms/step - accuracy: 0.5072 - loss: 1.2742 - val_accuracy: 0.5149 - val_loss: 1.2553
# Epoch 7/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 114s 253ms/step - accuracy: 0.5302 - loss: 1.2246 - val_accuracy: 0.5223 - val_loss: 1.2391
# Epoch 8/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 117s 261ms/step - accuracy: 0.5408 - loss: 1.1994 - val_accuracy: 0.5244 - val_loss: 1.2409
# Epoch 9/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 119s 264ms/step - accuracy: 0.5623 - loss: 1.1424 - val_accuracy: 0.5291 - val_loss: 1.2312
# Epoch 10/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 118s 262ms/step - accuracy: 0.5725 - loss: 1.1103 - val_accuracy: 0.5316 - val_loss: 1.2264
# Epoch 11/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 121s 269ms/step - accuracy: 0.5858 - loss: 1.0820 - val_accuracy: 0.5379 - val_loss: 1.2208
# Epoch 12/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 121s 270ms/step - accuracy: 0.6051 - loss: 1.0308 - val_accuracy: 0.5344 - val_loss: 1.2385
# Epoch 13/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 976s 2s/step - accuracy: 0.6119 - loss: 0.9974 - val_accuracy: 0.5371 - val_loss: 1.2424
# Epoch 14/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 134s 298ms/step - accuracy: 0.6225 - loss: 0.9643 - val_accuracy: 0.5495 - val_loss: 1.2247
# Epoch 15/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 117s 261ms/step - accuracy: 0.6416 - loss: 0.9240 - val_accuracy: 0.5418 - val_loss: 1.2433
# Epoch 16/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 125s 277ms/step - accuracy: 0.6450 - loss: 0.9116 - val_accuracy: 0.5463 - val_loss: 1.2669
# Epoch 17/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 115s 256ms/step - accuracy: 0.6582 - loss: 0.8681 - val_accuracy: 0.5496 - val_loss: 1.3306
# Epoch 18/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 114s 254ms/step - accuracy: 0.6704 - loss: 0.8363 - val_accuracy: 0.5454 - val_loss: 1.3224
# Epoch 19/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 118s 263ms/step - accuracy: 0.6747 - loss: 0.8101 - val_accuracy: 0.5479 - val_loss: 1.3472
# Epoch 20/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 114s 253ms/step - accuracy: 0.6837 - loss: 0.7957 - val_accuracy: 0.5520 - val_loss: 1.3608
# Epoch 21/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 116s 259ms/step - accuracy: 0.6981 - loss: 0.7702 - val_accuracy: 0.5457 - val_loss: 1.3927
# Epoch 22/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 486s 1s/step - accuracy: 0.6942 - loss: 0.7497 - val_accuracy: 0.5490 - val_loss: 1.3940
# Epoch 23/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 78s 174ms/step - accuracy: 0.7073 - loss: 0.7274 - val_accuracy: 0.5510 - val_loss: 1.4545
# Epoch 24/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 74s 164ms/step - accuracy: 0.7181 - loss: 0.7022 - val_accuracy: 0.5439 - val_loss: 1.5265
# Epoch 25/25
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 75s 167ms/step - accuracy: 0.7224 - loss: 0.6880 - val_accuracy: 0.5503 - val_loss: 1.4909
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training complete! Saved as emotion_model.h5

# %%
pip install opencv-python mediapipe numpy tensorflow keras
# Out:
# Requirement already satisfied: opencv-python in c:\users\akram\anaconda3\lib\site-packages (4.11.0.86)
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\akram\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: tensorflow in c:\users\akram\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\users\akram\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: absl-py in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (25.2.10)
# Collecting jax (from mediapipe)
#   Downloading jax-0.5.1-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.5.1-cp312-cp312-win_amd64.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (3.9.2)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting sentencepiece (from mediapipe)
#   Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: rich in c:\users\akram\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\akram\anaconda3\lib\site-packages (from keras) (0.14.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\akram\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\akram\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\akram\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\akram\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: pycparser in c:\users\akram\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: mdurl~=0.1 in c:\users\akram\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akram\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\akram\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Downloading mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
#    ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#    - -------------------------------------- 1.8/51.0 MB 12.6 MB/s eta 0:00:04
#    -- ------------------------------------- 2.9/51.0 MB 10.5 MB/s eta 0:00:05
#    --- ------------------------------------ 4.2/51.0 MB 7.6 MB/s eta 0:00:07
#    ---- ----------------------------------- 5.8/51.0 MB 8.0 MB/s eta 0:00:06
#    ------ --------------------------------- 8.9/51.0 MB 8.9 MB/s eta 0:00:05
#    ------- -------------------------------- 10.0/51.0 MB 8.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 13.9/51.0 MB 9.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 14.7/51.0 MB 9.9 MB/s eta 0:00:04
#    -------------- ------------------------- 18.1/51.0 MB 10.0 MB/s eta 0:00:04
#    -------------- ------------------------- 18.4/51.0 MB 9.3 MB/s eta 0:00:04
#    ----------------- ---------------------- 21.8/51.0 MB 9.8 MB/s eta 0:00:03
#    ------------------- -------------------- 25.2/51.0 MB 10.4 MB/s eta 0:00:03
#    -------------------- ------------------- 26.5/51.0 MB 10.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 29.4/51.0 MB 10.3 MB/s eta 0:00:03
#    ------------------------- -------------- 32.0/51.0 MB 10.5 MB/s eta 0:00:02
#    -------------------------- ------------- 34.3/51.0 MB 10.6 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.2/51.0 MB 10.5 MB/s eta 0:00:02
#    ------------------------------ --------- 39.1/51.0 MB 10.7 MB/s eta 0:00:02
#    -------------------------------- ------- 41.4/51.0 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 43.0/51.0 MB 10.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.4/51.0 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 47.2/51.0 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  49.8/51.0 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  50.9/51.0 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 51.0/51.0 MB 10.2 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Downloading jax-0.5.1-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 10.4 MB/s eta 0:00:00
# Downloading jaxlib-0.5.1-cp312-cp312-win_amd64.whl (65.2 MB)
#    ---------------------------------------- 0.0/65.2 MB ? eta -:--:--
#    - -------------------------------------- 2.4/65.2 MB 12.2 MB/s eta 0:00:06
#    -- ------------------------------------- 3.4/65.2 MB 10.6 MB/s eta 0:00:06
#    -- ------------------------------------- 4.2/65.2 MB 7.6 MB/s eta 0:00:08
#    --- ------------------------------------ 5.8/65.2 MB 7.3 MB/s eta 0:00:09
#    --- ------------------------------------ 6.3/65.2 MB 6.4 MB/s eta 0:00:10
#    ----- ---------------------------------- 8.4/65.2 MB 6.7 MB/s eta 0:00:09
#    ------ --------------------------------- 10.0/65.2 MB 6.9 MB/s eta 0:00:09
#    ------- -------------------------------- 11.8/65.2 MB 7.1 MB/s eta 0:00:08
#    -------- ------------------------------- 14.2/65.2 MB 7.5 MB/s eta 0:00:07
#    --------- ------------------------------ 16.3/65.2 MB 7.8 MB/s eta 0:00:07
#    ---------- ----------------------------- 17.8/65.2 MB 7.8 MB/s eta 0:00:07
#    ------------ --------------------------- 20.2/65.2 MB 8.1 MB/s eta 0:00:06
#    ------------- -------------------------- 22.5/65.2 MB 8.2 MB/s eta 0:00:06
#    --------------- ------------------------ 24.6/65.2 MB 8.3 MB/s eta 0:00:05
#    --------------- ------------------------ 26.0/65.2 MB 8.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 28.3/65.2 MB 8.4 MB/s eta 0:00:05
#    ------------------ --------------------- 30.1/65.2 MB 8.4 MB/s eta 0:00:05
#    ------------------- -------------------- 32.5/65.2 MB 8.6 MB/s eta 0:00:04
#    --------------------- ------------------ 34.9/65.2 MB 8.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 37.2/65.2 MB 8.9 MB/s eta 0:00:04
#    ------------------------ --------------- 39.8/65.2 MB 9.0 MB/s eta 0:00:03
#    ------------------------- -------------- 41.9/65.2 MB 9.1 MB/s eta 0:00:03
#    ------------------------- -------------- 42.2/65.2 MB 9.1 MB/s eta 0:00:03
#    --------------------------- ------------ 44.0/65.2 MB 8.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 46.1/65.2 MB 8.8 MB/s eta 0:00:03
#    ------------------------------ --------- 49.0/65.2 MB 8.9 MB/s eta 0:00:02
#    ------------------------------- -------- 50.6/65.2 MB 8.9 MB/s eta 0:00:02
#    -------------------------------- ------- 53.0/65.2 MB 8.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 55.8/65.2 MB 9.1 MB/s eta 0:00:02
#    ------------------------------------ --- 58.7/65.2 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 60.6/65.2 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 62.7/65.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  65.0/65.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 65.2/65.2 MB 9.1 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.3/46.2 MB 8.4 MB/s eta 0:00:06
#    -- ------------------------------------- 2.6/46.2 MB 5.8 MB/s eta 0:00:08
#    --- ------------------------------------ 3.9/46.2 MB 6.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 5.5/46.2 MB 6.5 MB/s eta 0:00:07
#    ------ --------------------------------- 7.6/46.2 MB 7.0 MB/s eta 0:00:06
#    -------- ------------------------------- 10.0/46.2 MB 7.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 12.8/46.2 MB 8.5 MB/s eta 0:00:04
#    ------------- -------------------------- 15.2/46.2 MB 8.9 MB/s eta 0:00:04
#    ------------- -------------------------- 15.2/46.2 MB 8.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 18.6/46.2 MB 8.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 20.7/46.2 MB 9.2 MB/s eta 0:00:03
#    --------------------- ------------------ 24.6/46.2 MB 9.6 MB/s eta 0:00:03
#    ---------------------- ----------------- 26.2/46.2 MB 9.6 MB/s eta 0:00:03
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 27.8/46.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------- -------------- 29.9/46.2 MB 6.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 32.8/46.2 MB 7.0 MB/s eta 0:00:02
#    ------------------------------ --------- 35.7/46.2 MB 7.3 MB/s eta 0:00:02
#    --------------------------------- ------ 39.1/46.2 MB 7.7 MB/s eta 0:00:01
#    ------------------------------------- -- 42.7/46.2 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  45.6/46.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 8.0 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.0-cp312-cp312-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/992.0 kB ? eta -:--:--
#    --------------------------------------- 992.0/992.0 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, opencv-contrib-python, sounddevice, jaxlib, jax, mediapipe
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\akram\\anaconda3\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip install --user mediapipe
# Out:
# Collecting mediapipe
#   Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: absl-py in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (25.2.10)
# Collecting jax (from mediapipe)
#   Using cached jax-0.5.1-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Using cached jaxlib-0.5.1-cp312-cp312-win_amd64.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: numpy<2 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (4.25.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Using cached sounddevice-0.5.1-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in c:\users\akram\anaconda3\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\akram\anaconda3\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in c:\users\akram\anaconda3\lib\site-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in c:\users\akram\anaconda3\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\akram\anaconda3\lib\site-packages (from jax->mediapipe) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akram\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\akram\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\akram\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
# Using cached sounddevice-0.5.1-py3-none-win_amd64.whl (363 kB)
# Using cached jax-0.5.1-py3-none-any.whl (2.4 MB)
# Using cached jaxlib-0.5.1-cp312-cp312-win_amd64.whl (65.2 MB)
# Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
# Installing collected packages: opencv-contrib-python, sounddevice, jaxlib, jax, mediapipe
# Successfully installed jax-0.5.1 jaxlib-0.5.1 mediapipe-0.10.21 opencv-contrib-python-4.11.0.86 sounddevice-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.getcwd())  # Prints the current working directory
print(os.listdir())  # Lists all files in the directory
# Out:
# C:\Users\akram
# ['#', '.anaconda', '.cache', '.cargo', '.conda', '.condarc', '.continuum', '.icesoft', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.matplotlib', '.ollama', '.openjfx', '.packettracer', '.rustup', '.VirtualBox', '.virtual_documents', '.vscode', '.wdm', '2203A52061_Lab Activity3.ipynb', '3D Objects', 'anaconda3', 'AppData', 'Application Data', 'AppMods', 'Cisco Packet Tracer 8.2.2', 'Contacts', 'Cookies', 'Create', 'Desktop', 'Documents', 'Downloads', 'emotion_model.h5', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'myenv', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{71e87238-c087-11ef-923c-9e762d00b26e}.TM.blf', 'NTUSER.DAT{71e87238-c087-11ef-923c-9e762d00b26e}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{71e87238-c087-11ef-923c-9e762d00b26e}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Oracle', 'PrintHood', 'Recent', 'Recorded Calls', 'Saved Games', 'Searches', 'SendTo', 'source', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Videos', 'virtual', 'VirtualBox VMs']
